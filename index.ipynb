# %% [markdown]
# # One-to-Many and Many-to-Many Joins - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge on One-to-Many and Many-to-many relationships!

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Query data including Many-to-Many relationships
# - Write queries that make use of Join Tables

# %% [markdown]
# ## One-to-Many and Many-to-Many Joins
# <img src='Database-Schema.png' width=550>

# %% [markdown]
# ## Employees and their Office (a One-to-One join)
#
# Return a list of all of the employees with their first name, last name and the city and state of the office that they work out of (if they have one). Include all employees and order them by their first name, then their last name.

# %%
#Your code here

import sqlite3
import pandas as pd
conn = sqlite3.connect('data.sqlite', detect_types=sqlite3.PARSE_COLNAMES)
cur = conn.cursor()

# %%
cur.execute("""SELECT firstName, lastName, city, state
                      FROM offices
                      JOIN employees
                      USING(officeCode)
                      ORDER BY firstName, lastName
                      ;""")
#pd.DataFrame(cur.fetchall())

# %% [markdown]
# ## Customers and their Orders (a One-to-Many join)
#
# Return a list of all of the customers. For each customer return a record for each of their order numbers, order dates and statuses.

# %%
# Your code here
cur.execute("""SELECT customerName, orderNumber, 
                        orderDate, status
                        FROM customers
                        JOIN orders
                        USING(customerNumber)
                        ;""")
# pd.DataFrame(cur.fetchall())

df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
# df - works

# %% [markdown]
# ## Orders and their Order Details (another One-to-Many join)
#
# Return a list of orders. For each order return a record for each order detail within the order.

# %%
# Your code here
cur.execute("""SELECT orderNumber, shippedDate, productCode, quantityOrdered, priceEach, orderLineNumber 
                        FROM orders
                        JOIN orderDetails 
                        USING(orderNumber)
                        ;""")
# pd.DataFrame(cur.fetchall())

df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df
# Out:
#      orderNumber shippedDate productCode quantityOrdered priceEach  \
# 0          10100  2003-01-10    S18_1749              30    136.00
# 1          10100  2003-01-10    S18_2248              50     55.09
# 2          10100  2003-01-10    S18_4409              22     75.46
# 3          10100  2003-01-10    S24_3969              49     35.29
# 4          10101  2003-01-11    S18_2325              25    108.06
# 5          10101  2003-01-11    S18_2795              26    167.06
# 6          10101  2003-01-11    S24_1937              45     32.53
# 7          10101  2003-01-11    S24_2022              46     44.35
# 8          10102  2003-01-14    S18_1342              39     95.55
# 9          10102  2003-01-14    S18_1367              41     43.13
# 10         10103  2003-02-02    S10_1949              26    214.30
# 11         10103  2003-02-02    S10_4962              42    119.67
# 12         10103  2003-02-02    S12_1666              27    121.64
# 13         10103  2003-02-02    S18_1097              35     94.50
# 14         10103  2003-02-02    S18_2432              22     58.34
# 15         10103  2003-02-02    S18_2949              27     92.19
# 16         10103  2003-02-02    S18_2957              35     61.84
# 17         10103  2003-02-02    S18_3136              25     86.92
# 18         10103  2003-02-02    S18_3320              46     86.31
# 19         10103  2003-02-02    S18_4600              36     98.07
# 20         10103  2003-02-02    S18_4668              41     40.75
# 21         10103  2003-02-02    S24_2300              36    107.34
# 22         10103  2003-02-02    S24_4258              25     88.62
# 23         10103  2003-02-02    S32_1268              31     92.46
# 24         10103  2003-02-02    S32_3522              45     63.35
# 25         10103  2003-02-02   S700_2824              42     94.07
# 26         10104  2003-02-01    S12_3148              34    131.44
# 27         10104  2003-02-01    S12_4473              41    111.39
# 28         10104  2003-02-01    S18_2238              24    135.90
# 29         10104  2003-02-01    S18_2319              29    122.73
# ...          ...         ...         ...             ...       ...
# 2966       10420                S24_3432              26    104.94
# 2967       10420                S24_3969              15     35.29
# 2968       10421                S18_2795              35    167.06
# 2969       10421                S24_2022              40     44.80
# 2970       10422                S18_1342              51     91.44
# 2971       10422                S18_1367              25     47.44
# 2972       10423                S18_2949              10     89.15
# 2973       10423                S18_2957              31     56.21
# 2974       10423                S18_3136              21     98.44
# 2975       10423                S18_3320              21     80.36
# 2976       10423                S24_4258              28     78.89
# 2977       10424                S10_1949              50    201.44
# 2978       10424                S12_1666              49    121.64
# 2979       10424                S18_1097              54    108.50
# 2980       10424                S18_4668              26     40.25
# 2981       10424                S32_3522              44     54.94
# 2982       10424               S700_2824              46     85.98
# 2983       10425                S10_4962              38    131.49
# 2984       10425                S12_4473              33     95.99
# 2985       10425                S18_2238              28    147.36
# 2986       10425                S18_2319              38    117.82
# 2987       10425                S18_2432              19     48.62
# 2988       10425                S18_3232              28    140.55
# 2989       10425                S18_4600              38    107.76
# 2990       10425                S24_1444              55     53.75
# 2991       10425                S24_2300              49    127.79
# 2992       10425                S24_2840              31     31.82
# 2993       10425                S32_1268              41     83.79
# 2994       10425                S32_2509              11     50.32
# 2995       10425                S50_1392              18     94.92
#
#      orderLineNumber
# 0                  3
# 1                  2
# 2                  4
# 3                  1
# 4                  4
# 5                  1
# 6                  3
# 7                  2
# 8                  2
# 9                  1
# 10                11
# 11                 4
# 12                 8
# 13                10
# 14                 2
# 15                12
# 16                14
# 17                13
# 18                16
# 19                 5
# 20                 9
# 21                 1
# 22                15
# 23                 3
# 24                 7
# 25                 6
# 26                 1
# 27                 9
# 28                 8
# 29                12
# ...              ...
# 2966              12
# 2967               3
# 2968               1
# 2969               2
# 2970               2
# 2971               1
# 2972               1
# 2973               3
# 2974               2
# 2975               5
# 2976               4
# 2977               6
# 2978               3
# 2979               5
# 2980               4
# 2981               2
# 2982               1
# 2983              12
# 2984               4
# 2985               3
# 2986               7
# 2987              10
# 2988               8
# 2989              13
# 2990               1
# 2991               9
# 2992               5
# 2993              11
# 2994               6
# 2995               2
#
# [2996 rows x 6 columns]

# %% [markdown]
# ## Orders, Order details and Product Details (a Many-to-Many Join)

# %% [markdown]
# Return a list of the orders with the the order information, and allthe product information for each product in the order.

# %%
# Your code here

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lab, you practiced your knowledge on One-to-Many and Many-to-many relationships!
